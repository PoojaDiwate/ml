# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report 
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree

# %%
data=pd.read_csv('/home/cslogin/mscii81/dataset/Decision_Tree_ Dataset.csv')
data
# Out:
#     Result  Initial_Payment  Last_Payment  Credit_Score  House_no
# 0      yes              201         10018           250      3046
# 1      yes              205         10016           395      3044
# 2      yes              257         10129           109      3251
# 3      yes              246         10064           324      3137
# 4      yes              117         10115           496      3094
# ..     ...              ...           ...           ...       ...
# 995     No              413         14914           523      4683
# 996     No              359         14423           927      4838
# 997     No              316         14872           613      4760
# 998     No              305         14926           897      4572
# 999     No              168         14798           834      4937
#
# [1000 rows x 5 columns]

# %%
x=data[['Initial_Payment','Last_Payment','Credit_Score']]
y=data['Result']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=50)

# %%
print(X_train)
# Out:
#      Initial_Payment  Last_Payment  Credit_Score
# 788              467         13412           358
# 579              349         12873           359
# 554              264         12672           901
# 882              186         14038           781
# 44               180         10806           388
# ..               ...           ...           ...
# 289              398         11944           278
# 109              112         11493           141
# 907              208         14043           850
# 480              121         12416           216
# 688              430         13020           350
#
# [700 rows x 3 columns]

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.87

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[141  19]
#  [ 20 120]]

# %%
plt.figure(figsize=(12,8))

# %%
tree.plot_tree(clf,filled=True,feature_names=['Initial_Payment','Last_Payment','Credit_Score'],class_names=['No','Yes'],rounded=True)
plt.show()
