# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df= pd.read_csv('/home/cslogin/mscii81/dataset/Iris.csv')

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
iris=load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['target']=iris.target

# %%
df.target
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
df['flowers_name']=df.target.apply(lambda x:iris.target_names[x])

# %%
x=iris.data

# %%
y=iris.target

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
svm = SVC(kernel='rbf')

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svm.predict(X_test)

# %%
y_pred
# Out:
# array([2, 0, 2, 2, 2, 1, 2, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 0, 0, 2, 0, 2,
#        1, 0, 0, 0, 0, 0, 0, 2])

# %%
from sklearn import linear_model

df=pd.read_csv('/home/cslogin/mscii81/dataset/housearea2.csv')

# %%
df.head()
# Out:
#    area  bedroom  age   price
# 0  2600      3.0   20  550000
# 1  3000      4.0   15  565000
# 2  3200      NaN   18  610000
# 3  3600      3.0   30  595000
# 4  4000      5.0    8  760000

# %%
df=df.fillna(df.mean())

# %%
df.head()
# Out:
#    area  bedroom  age   price
# 0  2600      3.0   20  550000
# 1  3000      4.0   15  565000
# 2  3200      3.6   18  610000
# 3  3600      3.0   30  595000
# 4  4000      5.0    8  760000

# %%
x=df[['area','bedroom','age']]
y=df[['price']]

# %%
x
# Out:
#    area  bedroom  age
# 0  2600      3.0   20
# 1  3000      4.0   15
# 2  3200      3.6   18
# 3  3600      3.0   30
# 4  4000      5.0    8
# 5  3300      3.0   12

# %%
y
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  595000
# 4  760000
# 5  623000

# %%
X_train_reg,X_test_reg,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
svm = SVC(kernel='linear')

# %%
svm.fit(X_train_reg,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = svm.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 y_pred = svm.predict(X_test)
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
# ...

# %%
y_pred
# Out:
# array([2, 0, 2, 2, 2, 1, 2, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 0, 0, 2, 0, 2,
#        1, 0, 0, 0, 0, 0, 0, 2])

# %%
score = mean_squared_error(y_pred, y_test)
score
# Out:
# 1097000000.0
